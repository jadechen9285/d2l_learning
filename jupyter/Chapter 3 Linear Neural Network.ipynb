# %% [markdown]
# ## 3.1.3 The Normal Distribution and Squared Loss

# %%
import math
from mxnet import np
from d2l import mxnet as d2l

# a function to compute normal distribution
def normal(x, mu, sigma):
    p = 1 / math.sqrt(2 * math.pi * sigma**2)
    return p * np.exp(-0.5 / sigma**2 * (x - mu)**2)

# %%
# Use numpy again for visualization 
x = np.arange(-7, 7, 0.01) 
# Mean and standard deviation pairs
params = [(0, 1), (0, 2), (3, 1)]

d2l.plot(x, [normal(x, mu, sigma) for mu, sigma in params], 
         xlabel='x', ylabel='p(x)', figsize=(4.5, 2.5),
         legend=[f'mean {mu}, std {sigma}' for mu, sigma in params])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-88dd5480a361> in <module>
#       4 params = [(0, 1), (0, 2), (3, 1)]
#       5
# ----> 6 d2l.plot(x, [normal(x, mu, sigma) for mu, sigma in params],
#       7          xlabel='x', ylabel='p(x)', figsize=(4.5, 2.5),
#       8          legend=[f'mean {mu}, std {sigma}' for mu, sigma in params])
#
# /usr/local/lib/python3.9/site-packages/d2l/mxnet.py in plot(X, Y, xlabel, ylabel, legend, xlim, ylim, xscale, yscale, fmts, figsize, axes)
#      84     for x, y, fmt in zip(X, Y, fmts):
#      85         if len(x):
# ---> 86             axes.plot(x, y, fmt)
#      87         else:
#      88             axes.plot(y, fmt)
#
# /usr/local/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
# -> 1607             self.add_line(line)
#    1608         self._request_autoscale_view(scalex=scalex, scaley=scaley)
#    1609         return lines
#
# /usr/local/lib/python3.9/site-packages/matplotlib/axes/_base.py in add_line(self, line)
#    2099             line.set_clip_path(self.patch)
#    2100
# -> 2101         self._update_line_limits(line)
#    2102         if not line.get_label():
#    2103             line.set_label('_line%d' % len(self.lines))
#
# /usr/local/lib/python3.9/site-packages/matplotlib/axes/_base.py in _update_line_limits(self, line)
#    2121         Figures out the data limit of the given line, updating self.dataLim.
#    2122         """
# -> 2123         path = line.get_path()
#    2124         if path.vertices.size == 0:
#    2125             return
#
# /usr/local/lib/python3.9/site-packages/matplotlib/lines.py in get_path(self)
#    1020         """
#    1021         if self._invalidy or self._invalidx:
# -> 1022             self.recache()
#    1023         return self._path
#    1024
#
# /usr/local/lib/python3.9/site-packages/matplotlib/lines.py in recache(self, always)
#     661         if always or self._invalidx:
#     662             xconv = self.convert_xunits(self._xorig)
# --> 663             x = _to_unmasked_float_array(xconv).ravel()
#     664         else:
#     665             x = self._x
#
# /usr/local/lib/python3.9/site-packages/matplotlib/cbook/__init__.py in _to_unmasked_float_array(x)
#    1331         return np.ma.asarray(x, float).filled(np.nan)
#    1332     else:
# -> 1333         return np.asarray(x, float)
#    1334
#    1335
#
# ValueError: setting an array element with a sequence. The requested array would exceed the maximum number of dimension of 32.
